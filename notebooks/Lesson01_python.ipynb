# %%
# وصل کردن Google Drive به Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1590/1832689450.py in <cell line: 0>()
#       1 # وصل کردن Google Drive به Colab
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os  # کتابخانه‌ای که کارهای مربوط به مسیر فایل و پوشه رو انجام می‌ده

# مسیر اصلی پروژه، داخل Drive خودت
base_path = "/content/drive/MyDrive/scRNA_project"

# مسیر مخصوص همین درس (درس ۱)
lesson_path = os.path.join(base_path, "lesson01")

# سه زیرپوشه‌ی درخواستی: کد، یادداشت، خروجی
for sub_folder in ["code", "notes", "output"]:
    full_path = os.path.join(lesson_path, sub_folder)
    os.makedirs(full_path, exist_ok=True)
    print(f"ساخته شد: {full_path}")
# Out:
# ساخته شد: /content/drive/MyDrive/scRNA_project/lesson01/code
# ساخته شد: /content/drive/MyDrive/scRNA_project/lesson01/notes
# ساخته شد: /content/drive/MyDrive/scRNA_project/lesson01/output

# %%
print("شروع تحلیل تک‌سلولی")
# Out:
# شروع تحلیل تک‌سلولی

# %%
print("تعداد سلول ها:" , 3000)
# Out:
# تعداد سلول ها: 3000

# %%
sample_name="patient_01"

# %%
cell_count=3000

# %%
print(cell_count)
# Out:
# 3000

# %%
cell_count=2847

# %%
print(cell_count)
# Out:
# 2847

# %%
passage_number=3

# %%
viability_percent=92.5

# %%
cell_type="fibroblast"

# %%
passed_qc=True

# %%
print(type(viability_percent))
# Out:
# <class 'float'>

# %%
# نصب کتابخانه Sacnpy
# !pip install scanpy
# وارد کردن کتابخانه به محیط کار با نام کوتاه sc
import scanpy as sc
#بارگذاری دیتاست آموزشی PBMC-3k (سه‌هزار سلول خونی، از پیش آماده‌شده توسط خود Scanpy)
adata=sc.datasets.pbmc3k()
# چاپ نسخه‌ی نرم‌افزار، برای اطمینان از نصب درست
print(sc.__version__)
# Out:
# ...
#   0%|          | 0.00/5.58M [00:00<?, ?B/s]
# 1.12.3
# /tmp/ipykernel_42706/2503371293.py:8: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print(sc.__version__)
