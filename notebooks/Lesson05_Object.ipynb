# %%
# ===== درس ۵: آشنایی با Object (شیء) =====

# ۱. اتصال Google Drive

from google.colab import drive
drive.mount('/content/drive')


# ۲. تعریف مسیرهای پروژه با pathlib

from pathlib import Path

PROJECT = Path("/content/drive/MyDrive/scRNA_project")
LESSON = PROJECT / "lesson05"
CODE = LESSON / "code"
NOTES = LESSON / "notes"
OUTPUT = LESSON / "output"


# ۳. ساخت پوشه‌های همین درس

for folder in [CODE, NOTES, OUTPUT]:
    folder.mkdir(parents=True, exist_ok=True)
    print("آماده شد:", folder)


# ۴. نصب Scanpy (فقط در صورت نیاز)

# !pip install scanpy


# ۵. وارد کردن Scanpy به محیط کار

import scanpy as sc


# ۶. بارگذاری دیتاست PBMC-3k

# چون این یک Notebook تازه است، حافظه‌ی Notebook قبلی را نداریم.
adata = sc.datasets.pbmc3k()
# Out:
# Mounted at /content/drive
# آماده شد: /content/drive/MyDrive/scRNA_project/lesson05/code
# آماده شد: /content/drive/MyDrive/scRNA_project/lesson05/notes
# آماده شد: /content/drive/MyDrive/scRNA_project/lesson05/output
# Collecting scanpy
#   Downloading scanpy-1.12.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting anndata>=0.10.8 (from scanpy)
#   Downloading anndata-0.13.3.post0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from scanpy) (2026.7.22)
# Collecting fast-array-utils>=1.4 (from fast-array-utils[accel,sparse]>=1.4->scanpy)
#   Downloading fast_array_utils-1.5-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.13/dist-packages (from scanpy) (3.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.13/dist-packages (from scanpy) (1.5.3)
# Collecting legacy-api-wrap>=1.5 (from scanpy)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=3.10 in /usr/local/lib/python3.13/dist-packages (from scanpy) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.13/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.13/dist-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba>=0.60 in /usr/local/lib/python3.13/dist-packages (from scanpy) (0.61.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.13/dist-packages (from scanpy) (2.1.3)
# Requirement already satisfied: packaging>=25 in /usr/local/lib/python3.13/dist-packages (from scanpy) (26.3)
# Collecting pandas>=2.3 (from scanpy)
#   Downloading pandas-3.0.5-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: patsy in /usr/local/lib/python3.13/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.13/dist-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.13/dist-packages (from scanpy) (1.6.1)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.13/dist-packages (from scanpy) (1.16.3)
# Collecting scverse-misc>=0.0.6 (from scanpy)
#   Downloading scverse_misc-0.1.3-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.13/dist-packages (from scanpy) (0.13.2)
# Collecting session-info2 (from scanpy)
#   Downloading session_info2-0.4.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.13/dist-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from scanpy) (4.67.3)
# Requirement already satisfied: umap-learn>=0.5.12 in /usr/local/lib/python3.13/dist-packages (from scanpy) (0.5.12)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.10.8->scanpy)
#   Downloading array_api_compat-1.15.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: typing-extensions>=4.16 in /usr/local/lib/python3.13/dist-packages (from anndata>=0.10.8->scanpy) (4.16.0)
# Collecting zarr>=3.1 (from anndata>=0.10.8->scanpy)
#   Downloading zarr-3.3.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10->scanpy) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10->scanpy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10->scanpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10->scanpy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba>=0.60->scanpy) (0.44.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.6->scanpy) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.10->scanpy) (1.17.0)
# Collecting pydantic-settings (from scverse-misc[settings]>=0.1.0->anndata>=0.10.8->scanpy)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.13/dist-packages (from scverse-misc[settings]>=0.1.0->anndata>=0.10.8->scanpy) (1.2.3)
# Collecting donfig>=0.8 (from zarr>=3.1->anndata>=0.10.8->scanpy)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.13/dist-packages (from zarr>=3.1->anndata>=0.10.8->scanpy) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr>=3.1->anndata>=0.10.8->scanpy)
#   Downloading numcodecs-0.16.5-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from donfig>=0.8->zarr>=3.1->anndata>=0.10.8->scanpy) (6.0.3)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings->scverse-misc[settings]>=0.1.0->anndata>=0.10.8->scanpy) (2.13.4)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings->scverse-misc[settings]>=0.1.0->anndata>=0.10.8->scanpy) (0.4.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.7.0->pydantic-settings->scverse-misc[settings]>=0.1.0->anndata>=0.10.8->scanpy) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.7.0->pydantic-settings->scverse-misc[settings]>=0.1.0->anndata>=0.10.8->scanpy) (2.46.4)
# Downloading scanpy-1.12.4-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 53.2 MB/s eta 0:00:00
# Downloading anndata-0.13.3.post0-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.8/188.8 kB 13.2 MB/s eta 0:00:00
# Downloading fast_array_utils-1.5-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 2.9 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading pandas-3.0.5-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 73.0 MB/s eta 0:00:00
# Downloading scverse_misc-0.1.3-py3-none-any.whl (24 kB)
# Downloading session_info2-0.4.2-py3-none-any.whl (17 kB)
# Downloading array_api_compat-1.15.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.0 MB/s eta 0:00:00
# Downloading zarr-3.3.0-py3-none-any.whl (363 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.7/363.7 kB 25.0 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 81.4 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: session-info2, numcodecs, legacy-api-wrap, donfig, array-api-compat, zarr, scverse-misc, pandas, fast-array-utils, pydantic-settings, anndata, scanpy
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.3, but you have pandas 3.0.5 which is incompatible.
# Successfully installed anndata-0.13.3.post0 array-api-compat-1.15.0 donfig-0.8.1.post1 fast-array-utils-1.5 legacy-api-wrap-1.5 numcodecs-0.16.5 pandas-3.0.5 pydantic-settings-2.15.0 scanpy-1.12.4 scverse-misc-0.1.3 session-info2-0.4.2 zarr-3.3.0
#   0%|          | 0.00/5.58M [00:00<?, ?B/s]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'
#     layers: None (.X)

# %%
type(adata)
# Out:
# anndata.AnnData

# %%
adata.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 2286884 stored elements and shape (2700, 32738)>

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACATACAACCAC-1, AAACATTGAGCTAC-1, AAACATTGATCAGC-1, AAACCGTGCTTCCG-1, AAACCGTGTATGCG-1, AAACGCACTGGTAC-1, AAACGCTGACCAGT-1, AAACGCTGGTTCTT-1, AAACGCTGTAGCCA-1, AAACGCTGTTTCTG-1, AAACTTGAAAAACG-1, AAACTTGATCCAGA-1, AAAGAGACGAGATA-1, AAAGAGACGCGAGA-1, AAAGAGACGGACTT-1, AAAGAGACGGCATT-1, AAAGATCTGGGCAA-1, AAAGCAGAAGCCAT-1, AAAGCAGATATCGG-1, AAAGCCTGTATGCG-1, AAAGGCCTGTCTAG-1, AAAGTTTGATCACG-1, AAAGTTTGGGGTGA-1, AAAGTTTGTAGAGA-1, AAAGTTTGTAGCGT-1, AAATCAACAATGCC-1, AAATCAACACCAGT-1, AAATCAACCAGGAG-1, AAATCAACCCTATT-1, AAATCAACGGAAGC-1, AAATCAACTCGCAA-1, AAATCATGACCACA-1, AAATCCCTCCACAA-1, AAATCCCTGCTATG-1, AAATGTTGAACGAA-1, AAATGTTGCCACAA-1, AAATGTTGTGGCAT-1, AAATTCGAAGGTTC-1, AAATTCGAATCACG-1, AAATTCGAGCTGAT-1, AAATTCGAGGAGTG-1, AAATTCGATTCTCA-1, AAATTGACACGACT-1, AAATTGACTCGCTC-1, AACAAACTCATTTC-1, AACAAACTTTCGTT-1, AACAATACGACGAG-1, AACACGTGCAGAGG-1, AACACGTGGAAAGT-1, AACACGTGGAACCT-1, AACACGTGGCTACA-1, AACACGTGTACGAC-1, AACAGCACAAGAGT-1, AACATTGATGGGAG-1, AACCAGTGATACCG-1, AACCCAGATCGCTC-1, AACCGATGCTCCCA-1, AACCGATGGTCATG-1, AACCGATGTTCTAC-1, AACCGCCTAGCGTT-1, AACCGCCTCTACGA-1, AACCTACTGTGAGG-1, AACCTACTGTGTTG-1, AACCTTACGAGACG-1, AACCTTACGCGAGA-1, AACCTTACTAACGC-1, AACCTTTGGACGGA-1, AACCTTTGTACGCA-1, AACGCAACAAGTAG-1, AACGCATGACCCAA-1, AACGCATGCCTTCG-1, AACGCATGTACTTC-1, AACGCCCTCGGGAA-1, AACGCCCTCGTACA-1, AACGCCCTGCTTAG-1, AACGCCCTGGCATT-1, AACGTCGAGTATCG-1, AACGTGTGAAAGCA-1, AACGTGTGGCGGAA-1, AACGTGTGTCCAAG-1, AACGTGTGTGCTTT-1, AACTACCTTAGAGA-1, AACTCACTCAAGCT-1, AACTCACTTGGAGG-1, AACTCGGAAAGTGA-1, AACTCGGAAGGTCT-1, AACTCTTGCAGGAG-1, AACTGTCTCCCTTG-1, AACTTGCTACGCTA-1, AACTTGCTGGGACA-1, AAGAACGAGTGTTG-1, AAGAAGACGTAGGG-1, AAGACAGAAGTCTG-1, AAGACAGAGGATCT-1, AAGACAGATTACCT-1, AAGAGATGGGTAGG-1, AAGATGGAAAACAG-1, AAGATGGAGAACTC-1, AAGATGGAGATAAG-1, AAGATTACAACCTG-1, ...]
#
# [2700 rows x 0 columns]

# %%
adata.var
# Out:
#                      gene_ids
# index
# MIR1302-10    ENSG00000243485
# FAM138A       ENSG00000237613
# OR4F5         ENSG00000186092
# RP11-34P13.7  ENSG00000238009
# RP11-34P13.8  ENSG00000239945
# ...                       ...
# AC145205.1    ENSG00000215635
# BAGE5         ENSG00000268590
# CU459201.1    ENSG00000251180
# AC002321.2    ENSG00000215616
# AC002321.1    ENSG00000215611
#
# [32738 rows x 1 columns]

# %%
adata.shape
# Out:
# (2700, 32738)

# %%
type(adata.X)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
type(adata.obs)
# Out:
# pandas.DataFrame

# %%
adata.obs.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACATACAACCAC-1, AAACATTGAGCTAC-1, AAACATTGATCAGC-1, AAACCGTGCTTCCG-1, AAACCGTGTATGCG-1]

# %%
adata.var.head()
# Out:
#                      gene_ids
# index
# MIR1302-10    ENSG00000243485
# FAM138A       ENSG00000237613
# OR4F5         ENSG00000186092
# RP11-34P13.7  ENSG00000238009
# RP11-34P13.8  ENSG00000239945
